# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy.stats as ss
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.utils import resample

from tensorflow.keras.metrics import BinaryAccuracy
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight

RANDOM_SEED = 2080
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
df = pd.read_csv("../icu_train.csv")
df_test = pd.read_csv("../icu_test.csv")
print(df.shape)
df.columns
# Out:
# (73370, 141)
# Index(['age', 'bmi', 'elective_surgery', 'gender', 'pre_icu_los_days',
#        'apache_post_operative', 'arf_apache', 'bun_apache',
#        'creatinine_apache', 'gcs_motor_apache',
#        ...
#        'apache_2_diagnosis_219.0', 'apache_2_diagnosis_301.0',
#        'apache_2_diagnosis_302.0', 'apache_2_diagnosis_303.0',
#        'apache_2_diagnosis_304.0', 'apache_2_diagnosis_305.0',
#        'apache_2_diagnosis_306.0', 'apache_2_diagnosis_307.0',
#        'apache_2_diagnosis_308.0', 'hospital_death'],
#       dtype='object', length=141)

# %%
if "Unnamed: 0" in df.columns:
    df = df.drop(columns=["Unnamed: 0"])

if "Unnamed: 0" in df_test.columns:
    df_test = df_test.drop(columns=["Unnamed: 0"])

X_train = df.drop(columns=["hospital_death"])
y_train = df["hospital_death"].astype(int)
X_test = df_test.drop(columns=["hospital_death"])
y_test = df_test["hospital_death"].astype(int)

# %%
def evaluate(name, y_true, y_prob, threshold = .5):
    y_pred = (y_prob >= threshold).astype(int)

    acc = accuracy_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_prob)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, average='binary')
    f1_w = f1_score(y_true, y_pred, average='weighted')

    print(f"\n=== {name} ===")
    print(f"Accuracy : {acc:.4f}")
    print(f"AUROC : {auc:.4f}")
    print(f"Precision : {prec:.4f}")
    print(f"Recall : {rec:.4f}")
    print(f"F1 : {f1:.4f}")
    print(f"F1_weighted : {f1_w:.4f}")
    print("-" * 40)

    return {"model": name, "acc": acc, "auc": auc, "prec": prec, "rec": rec, "f1": f1, "f1_weighted": f1_w}

def plot_metric(results, metric='f1'):
    df = pd.DataFrame(results)
    
    df['run'] = df.groupby('model').cumcount() + 1
    df['label'] = df['model'] + ' #' + df['run'].astype(str)
    
    count = len(df)
    width = max(8, count * 0.4)
    _, ax = plt.subplots(figsize=(width, 6))
    
    ax.bar(df['label'], df[metric])
    ax.set_ylabel(metric.upper() + ' Score')
    ax.set_title(f'{metric.upper()} Score by Model and Run')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

classes = np.unique(y_train)
cw = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weight_dict = dict(zip(classes, cw))
sample_weight_train = np.array([class_weight_dict[y] for y in y_train])

results = []

# %%
X = X_train.copy()
y = y_train.copy()
X_majority = X[y == 0]
y_majority = y[y == 0]
X_minority = X[y == 1]
y_minority = y[y == 1]

X_majority_down, y_majority_down = resample(
    X_majority, y_majority,
    replace=False,
    n_samples=len(y_minority),
    random_state=RANDOM_SEED)

X_bal = pd.concat([X_minority, X_majority_down], axis=0)
y_bal = pd.concat([y_minority, y_majority_down], axis=0)

perm = np.random.RandomState(RANDOM_SEED).permutation(len(y_bal))
X_bal = X_bal.iloc[perm].reset_index(drop=True)
y_bal = y_bal.iloc[perm].reset_index(drop=True)

print("Balanced training set class counts:")
print(y_bal.value_counts())


log_clf_bal = LogisticRegression(
    max_iter=3000,
    penalty="l2",
    solver="lbfgs",
    n_jobs=-1,
    random_state=RANDOM_SEED)
log_clf_bal.fit(X_bal, y_bal)

y_pred_bal = log_clf_bal.predict(X_test)
y_prob_lr = log_clf_bal.predict_proba(X_test)[:, 1]
print("=== Downsampled Logistic Regression ===")
print(classification_report(y_test, y_pred_bal, digits=4))

results.append(evaluate("Logistic Regression", y_test, y_pred_bal))
# Out:
# Balanced training set class counts:
# hospital_death
# 0    6332
# 1    6332
# Name: count, dtype: int64
# === Downsampled Logistic Regression ===
#               precision    recall  f1-score   support
#
#            0     0.9742    0.8032    0.8805     16760
#            1     0.2712    0.7751    0.4018      1583
#
#     accuracy                         0.8008     18343
#    macro avg     0.6227    0.7892    0.6411     18343
# weighted avg     0.9136    0.8008    0.8392     18343
#
#
# === Logistic Regression ===
# Accuracy : 0.8008
# AUROC : 0.7892
# Precision : 0.2712
# Recall : 0.7751
# F1 : 0.4018
# F1_weighted : 0.8392
# ----------------------------------------

# %%
param_dist = {
    'n_estimators': [100,200,400,800],
    'learning_rate': [0.01,0.03,0.1],
    'max_depth': [3,5,7],
    'subsample': [0.6,0.8,1.0],
    'colsample_bytree': [0.6,0.8,1.0],
}

xgb = XGBClassifier(objective='binary:logistic', eval_metric='auc', random_state=42)
search_xgb = RandomizedSearchCV(
    xgb, param_distributions=param_dist,
    n_iter=30, cv=4, scoring='roc_auc',
    random_state=2080, n_jobs=-1, verbose=1
)

search_xgb.fit(X_bal, y_bal)
print("Best XGB params:", search_xgb.best_params_)
xgb_clf = search_xgb.best_estimator_
# Out:
# Fitting 4 folds for each of 30 candidates, totalling 120 fits
# Best XGB params: {'subsample': 0.6, 'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.03, 'colsample_bytree': 1.0}

# %%
# xgb_clf = XGBClassifier(
#     n_estimators=800,
#     learning_rate=0.03,
#     max_depth=5,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum(),
#     objective="binary:logistic",
#     eval_metric="auc",
#     random_state=RANDOM_SEED,
#     n_jobs=-1)

xgb_clf.fit(X_bal, y_bal, verbose=False)
y_prob_xgb = xgb_clf.predict_proba(X_test)[:, 1]
y_pred_xgb = xgb_clf.predict(X_test)


results.append(evaluate("XGBoost", y_test, y_prob_xgb))
# Out:
# === XGBoost ===
# Accuracy : 0.8062
# AUROC : 0.8916
# Precision : 0.2828
# Recall : 0.8105
# F1 : 0.4193
# F1_weighted : 0.8436
# ----------------------------------------

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical

X_train_np = X_train.to_numpy().astype("float32")
X_test_np  = X_test.to_numpy().astype("float32")

y_train_int = y_train.to_numpy().astype("int32")
y_test_int  = y_test.to_numpy().astype("int32")

y_train_cat = to_categorical(y_train_int, num_classes=2).astype("float32")
y_test_cat  = to_categorical(y_test_int,  num_classes=2).astype("float32")

model_mc = Sequential([
    Dense(512, activation='relu', input_shape=(X_train_np.shape[1],)),
    BatchNormalization(),
    Dropout(0.25),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(2, activation="softmax")])

model_mc.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])

history_mc = model_mc.fit(
    X_train_np,
    y_train_cat,
    validation_split=0.15,
    epochs=50,
    batch_size=256)

loss, acc, auc_mc = model_mc.evaluate(X_test_np, y_test_cat, verbose=0)
print(f"Test loss: {loss:.4f}, Test acc: {acc:.4f}, Test AUC: {auc_mc:.4f}")

y_prob_mc = model_mc.predict(X_test_np, batch_size=256)
y_pred_mc = y_prob_mc.argmax(axis=1)

print(evaluate("MultiClass MLP", y_test_int, y_prob_mc[:,1]))
print(classification_report(y_test_int, y_pred_mc, digits=4))
print("ROC AUC (class-1):", roc_auc_score(y_test_int, y_prob_mc[:,1]))
results.append(evaluate("MultiClass MLP", y_test_int, y_prob_mc[:,1]))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 244/244 [==============================] - 2s 5ms/step - loss: 0.3800 - accuracy: 0.8563 - auc: 0.9135 - val_loss: 0.2073 - val_accuracy: 0.9311 - val_auc: 0.9709
# Epoch 2/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.2272 - accuracy: 0.9197 - auc: 0.9664 - val_loss: 0.1911 - val_accuracy: 0.9323 - val_auc: 0.9762
# Epoch 3/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.2030 - accuracy: 0.9256 - auc: 0.9737 - val_loss: 0.1840 - val_accuracy: 0.9330 - val_auc: 0.9781
# Epoch 4/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1941 - accuracy: 0.9282 - auc: 0.9761 - val_loss: 0.1820 - val_accuracy: 0.9334 - val_auc: 0.9787
# Epoch 5/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1853 - accuracy: 0.9308 - auc: 0.9783 - val_loss: 0.1841 - val_accuracy: 0.9332 - val_auc: 0.9783
# Epoch 6/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1817 - accuracy: 0.9312 - auc: 0.9792 - val_loss: 0.1823 - val_accuracy: 0.9343 - val_auc: 0.9786
# Epoch 7/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1758 - accuracy: 0.9336 - auc: 0.9806 - val_loss: 0.1849 - val_accuracy: 0.9337 - val_auc: 0.9780
# Epoch 8/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1740 - accuracy: 0.9331 - auc: 0.9810 - val_loss: 0.1847 - val_accuracy: 0.9323 - val_auc: 0.9783
# Epoch 9/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1672 - accuracy: 0.9357 - auc: 0.9824 - val_loss: 0.1889 - val_accuracy: 0.9305 - val_auc: 0.9774
# Epoch 10/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1632 - accuracy: 0.9374 - auc: 0.9833 - val_loss: 0.1918 - val_accuracy: 0.9280 - val_auc: 0.9769
# Epoch 11/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1597 - accuracy: 0.9388 - auc: 0.9840 - val_loss: 0.1906 - val_accuracy: 0.9323 - val_auc: 0.9773
# Epoch 12/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1530 - accuracy: 0.9407 - auc: 0.9853 - val_loss: 0.1967 - val_accuracy: 0.9288 - val_auc: 0.9762
# Epoch 13/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1495 - accuracy: 0.9414 - auc: 0.9861 - val_loss: 0.1960 - val_accuracy: 0.9303 - val_auc: 0.9771
# Epoch 14/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1447 - accuracy: 0.9438 - auc: 0.9869 - val_loss: 0.2038 - val_accuracy: 0.9251 - val_auc: 0.9753
# Epoch 15/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1415 - accuracy: 0.9448 - auc: 0.9875 - val_loss: 0.2051 - val_accuracy: 0.9269 - val_auc: 0.9746
# Epoch 16/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1363 - accuracy: 0.9469 - auc: 0.9883 - val_loss: 0.2076 - val_accuracy: 0.9269 - val_auc: 0.9743
# Epoch 17/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1306 - accuracy: 0.9480 - auc: 0.9893 - val_loss: 0.2100 - val_accuracy: 0.9257 - val_auc: 0.9743
# Epoch 18/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1261 - accuracy: 0.9499 - auc: 0.9900 - val_loss: 0.2190 - val_accuracy: 0.9282 - val_auc: 0.9734
# Epoch 19/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1215 - accuracy: 0.9509 - auc: 0.9907 - val_loss: 0.2228 - val_accuracy: 0.9258 - val_auc: 0.9728
# Epoch 20/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.1156 - accuracy: 0.9542 - auc: 0.9916 - val_loss: 0.2292 - val_accuracy: 0.9212 - val_auc: 0.9724
# Epoch 21/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1107 - accuracy: 0.9553 - auc: 0.9923 - val_loss: 0.2326 - val_accuracy: 0.9252 - val_auc: 0.9719
# Epoch 22/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1059 - accuracy: 0.9582 - auc: 0.9929 - val_loss: 0.2408 - val_accuracy: 0.9224 - val_auc: 0.9706
# Epoch 23/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.1022 - accuracy: 0.9597 - auc: 0.9933 - val_loss: 0.2464 - val_accuracy: 0.9220 - val_auc: 0.9698
# Epoch 24/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0985 - accuracy: 0.9600 - auc: 0.9938 - val_loss: 0.2498 - val_accuracy: 0.9224 - val_auc: 0.9693
# Epoch 25/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0938 - accuracy: 0.9623 - auc: 0.9944 - val_loss: 0.2565 - val_accuracy: 0.9217 - val_auc: 0.9690
# Epoch 26/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0920 - accuracy: 0.9641 - auc: 0.9945 - val_loss: 0.2561 - val_accuracy: 0.9234 - val_auc: 0.9691
# Epoch 27/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0877 - accuracy: 0.9653 - auc: 0.9950 - val_loss: 0.2629 - val_accuracy: 0.9221 - val_auc: 0.9680
# Epoch 28/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0839 - accuracy: 0.9669 - auc: 0.9955 - val_loss: 0.2688 - val_accuracy: 0.9202 - val_auc: 0.9679
# Epoch 29/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0807 - accuracy: 0.9681 - auc: 0.9958 - val_loss: 0.2765 - val_accuracy: 0.9175 - val_auc: 0.9671
# Epoch 30/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0797 - accuracy: 0.9686 - auc: 0.9959 - val_loss: 0.2763 - val_accuracy: 0.9226 - val_auc: 0.9674
# Epoch 31/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0770 - accuracy: 0.9694 - auc: 0.9960 - val_loss: 0.2819 - val_accuracy: 0.9215 - val_auc: 0.9670
# Epoch 32/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0749 - accuracy: 0.9703 - auc: 0.9963 - val_loss: 0.2853 - val_accuracy: 0.9195 - val_auc: 0.9668
# Epoch 33/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0700 - accuracy: 0.9739 - auc: 0.9967 - val_loss: 0.2987 - val_accuracy: 0.9202 - val_auc: 0.9659
# Epoch 34/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0682 - accuracy: 0.9739 - auc: 0.9968 - val_loss: 0.3018 - val_accuracy: 0.9214 - val_auc: 0.9656
# Epoch 35/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0678 - accuracy: 0.9745 - auc: 0.9968 - val_loss: 0.3003 - val_accuracy: 0.9200 - val_auc: 0.9654
# Epoch 36/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0659 - accuracy: 0.9745 - auc: 0.9971 - val_loss: 0.3077 - val_accuracy: 0.9234 - val_auc: 0.9661
# Epoch 37/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0642 - accuracy: 0.9745 - auc: 0.9973 - val_loss: 0.3135 - val_accuracy: 0.9183 - val_auc: 0.9643
# Epoch 38/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0611 - accuracy: 0.9768 - auc: 0.9974 - val_loss: 0.3113 - val_accuracy: 0.9209 - val_auc: 0.9646
# Epoch 39/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0618 - accuracy: 0.9764 - auc: 0.9974 - val_loss: 0.3119 - val_accuracy: 0.9185 - val_auc: 0.9656
# Epoch 40/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0589 - accuracy: 0.9768 - auc: 0.9977 - val_loss: 0.3243 - val_accuracy: 0.9214 - val_auc: 0.9652
# Epoch 41/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0572 - accuracy: 0.9781 - auc: 0.9978 - val_loss: 0.3255 - val_accuracy: 0.9204 - val_auc: 0.9639
# Epoch 42/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0601 - accuracy: 0.9770 - auc: 0.9975 - val_loss: 0.3348 - val_accuracy: 0.9214 - val_auc: 0.9634
# Epoch 43/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0565 - accuracy: 0.9779 - auc: 0.9977 - val_loss: 0.3321 - val_accuracy: 0.9242 - val_auc: 0.9649
# Epoch 44/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0561 - accuracy: 0.9785 - auc: 0.9977 - val_loss: 0.3315 - val_accuracy: 0.9235 - val_auc: 0.9642
# Epoch 45/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0520 - accuracy: 0.9806 - auc: 0.9981 - val_loss: 0.3329 - val_accuracy: 0.9204 - val_auc: 0.9634
# Epoch 46/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0524 - accuracy: 0.9801 - auc: 0.9981 - val_loss: 0.3514 - val_accuracy: 0.9245 - val_auc: 0.9633
# Epoch 47/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0530 - accuracy: 0.9795 - auc: 0.9980 - val_loss: 0.3463 - val_accuracy: 0.9238 - val_auc: 0.9632
# Epoch 48/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0515 - accuracy: 0.9800 - auc: 0.9981 - val_loss: 0.3446 - val_accuracy: 0.9242 - val_auc: 0.9638
# Epoch 49/50
# 244/244 [==============================] - 1s 4ms/step - loss: 0.0506 - accuracy: 0.9806 - auc: 0.9982 - val_loss: 0.3551 - val_accuracy: 0.9233 - val_auc: 0.9629
# Epoch 50/50
# 244/244 [==============================] - 1s 5ms/step - loss: 0.0489 - accuracy: 0.9813 - auc: 0.9983 - val_loss: 0.3467 - val_accuracy: 0.9219 - val_auc: 0.9638
# Test loss: 0.3851, Test acc: 0.9184, Test AUC: 0.9591
# 72/72 [==============================] - 0s 974us/step
#
# === MultiClass MLP ===
# Accuracy : 0.9184
# AUROC : 0.8508
# Precision : 0.5432
# Recall : 0.3455
# F1 : 0.4224
# F1_weighted : 0.9101
# ----------------------------------------
# {'model': 'MultiClass MLP', 'acc': 0.9184430027803522, 'auc': 0.8507982336188349, 'prec': 0.5431976166832175, 'rec': 0.34554643082754266, 'f1': 0.4223938223938224, 'f1_weighted': 0.9100630072412086}
#               precision    recall  f1-score   support
#
#            0     0.9402    0.9726    0.9561     16760
#            1     0.5432    0.3455    0.4224      1583
#
#     accuracy                         0.9184     18343
#    macro avg     0.7417    0.6591    0.6893     18343
# weighted avg     0.9060    0.9184    0.9101     18343
#
# ROC AUC (class-1): 0.8507982336188349
#
# === MultiClass MLP ===
# Accuracy : 0.9184
# AUROC : 0.8508
# Precision : 0.5432
# Recall : 0.3455
# F1 : 0.4224
# F1_weighted : 0.9101
# ----------------------------------------

# %%
plot_metric(results, metric='acc')
# Other metrics are in the output above. The names don't exactly map, though, because I'm difficult. 
#"model": name, "acc": acc, "auc": auc, "prec": prec, "rec": rec, "f1": f1, "f1_weighted": f1_w}

# %%
fpr_lr,  tpr_lr,  _ = roc_curve(y_test, y_prob_lr)
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, y_prob_xgb)
fpr_mlp, tpr_mlp, _ = roc_curve(y_test, y_prob_mc[:,1])

auc_lr  = auc(fpr_lr,  tpr_lr)
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_mlp = auc(fpr_mlp, tpr_mlp)

plt.figure(figsize=(8, 6))
plt.plot(fpr_lr,  tpr_lr,  label=f'LogReg (AUC = {auc_lr:.3f})')
plt.plot(fpr_xgb, tpr_xgb, label=f'XGBoost (AUC = {auc_xgb:.3f})')
plt.plot(fpr_mlp, tpr_mlp, label=f'MLP (AUC = {auc_mlp:.3f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance (AUC = 0.5)')

plt.title('ROC Curves Comparison')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)

# %%
eth_cols = ['ethnicity_Asian', 'ethnicity_Caucasian', 'ethnicity_Hispanic', 'ethnicity_Native American', 'ethnicity_Other/Unknown']

def decode_onehot(df, cols, prefix):
    def pick(row):
        ones = [c for c in cols if row[c] == 1]
        if len(ones) == 1:
            return ones[0].split(prefix,1)[1]
        else:
            return 'Unknown'
    return df.apply(pick, axis=1)

df_test = df_test.copy()
df_test['ethnicity_cat'] = decode_onehot(df_test, eth_cols, 'ethnicity_')

hosp_cols = [c for c in df_test.columns if c.startswith('hospital_admit_source_')]

df_test['hosp_admit_src_cat'] = decode_onehot(df_test, hosp_cols, 'hospital_admit_source_')

df_test['age_group'] = pd.qcut(df_test['age'], q=[0, 0.33, 0.66, 1.0], labels=['young','mid','old'])

demo_axes = {
    'gender' : df_test['gender'].unique(),
    'ethnicity_cat' : df_test['ethnicity_cat'].unique(),
    'hosp_admit_src_cat': df_test['hosp_admit_src_cat'].unique(),
    'age_group' : ['young','mid','old']}

models = [
    ('LogReg', y_pred_bal,  y_prob_lr),
    ('XGBoost', y_pred_xgb, y_prob_xgb),
    ('MLP', y_pred_mc, y_prob_mc[:,1]),]


for axis in ['gender','ethnicity_cat','hosp_admit_src_cat','age_group']:
    counts = df_test[axis].value_counts().sort_index()
    prevalence = df_test.groupby(axis)['hospital_death'].mean().loc[counts.index]
    fig, (ax1,ax2) = plt.subplots(1,2,figsize=(10,4))
    counts.plot.bar(ax=ax1); ax1.set_title(f'{axis} counts'); ax1.set_xlabel(axis); ax1.set_ylabel('n samples')
    prevalence.plot.bar(ax=ax2); ax2.set_title(f'{axis} positive rate'); ax2.set_xlabel(axis); ax2.set_ylabel('hospital_death rate')
# Out:
# /var/folders/q4/5kbb7bd12kjf1rfmbkt6543r0000gn/T/ipykernel_10411/3597834849.py:35: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prevalence = df_test.groupby(axis)['hospital_death'].mean().loc[counts.index]

# %%
records = []
for model_name, y_pred, y_prob in models:
    for axis, groups in demo_axes.items():
        for grp in groups:
            mask = df_test[axis] == grp
            if mask.sum() < 30:
                continue
            yt = y_test[mask]
            yp = y_pred[mask]
            yp_prob = y_prob[mask]

            records.append({
                'model' : model_name,
                'demographic': axis,
                'group': grp,
                'n_samples': int(mask.sum()),
                'accuracy': accuracy_score(yt, yp),
                'auc': roc_auc_score(yt, yp_prob) if yt.nunique()>1 else float('nan'),
                'precision': precision_score(yt, yp, zero_division=0),
                'recall': recall_score(yt, yp, zero_division=0),
                'f1': f1_score(yt, yp, zero_division=0)})

df_subgroup = pd.DataFrame(records)

table = df_subgroup.pivot_table(index=['demographic','group'], columns='model', values=['accuracy','auc','f1'], aggfunc='first')

print(table)
# Out:
#                                          accuracy                      \
# model                                      LogReg       MLP   XGBoost
# demographic        group
# age_group          mid                   0.804134  0.912073  0.794127
#                    old                   0.701277  0.884766  0.723234
#                    young                 0.889360  0.955587  0.894382
# ethnicity_cat      Asian                 0.795082  0.938525  0.782787
#                    Caucasian             0.800488  0.916120  0.806211
#                    Hispanic              0.742857  0.907483  0.771429
#                    Native American       0.820988  0.950617  0.827160
#                    Other/Unknown         0.818687  0.941046  0.844271
#                    Unknown               0.815509  0.923974  0.803345
# gender             0                     0.800728  0.919077  0.812968
#                    1                     0.800875  0.917701  0.798392
# hosp_admit_src_cat Direct Admit          0.774902  0.918431  0.789804
#                    Emergency Department  0.805362  0.922520  0.811528
#                    Floor                 0.656055  0.854557  0.694132
#                    Operating Room        0.904786  0.959194  0.900252
#                    Other Hospital        0.703030  0.857576  0.748485
#                    Other ICU             0.711538  0.750000  0.769231
#                    PACU                  0.929648  0.979899  0.889447
#                    Recovery Room         0.925801  0.959528  0.932546
#                    Step-Down Unit (SDU)  0.644144  0.819820  0.657658
#                    Unknown               0.798996  0.919031  0.791357
#
#                                               auc                      \
# model                                      LogReg       MLP   XGBoost
# demographic        group
# age_group          mid                   0.847686  0.838083  0.873372
#                    old                   0.842854  0.812226  0.868255
#                    young                 0.904119  0.885614  0.924790
# ethnicity_cat      Asian                 0.893559  0.866519  0.898722
#                    Caucasian             0.871421  0.849831  0.893552
#                    Hispanic              0.873556  0.885484  0.899396
#                    Native American       0.814013  0.834395  0.802548
#                    Other/Unknown         0.903816  0.876369  0.910964
#                    Unknown               0.835994  0.825889  0.867512
# gender             0                     0.869120  0.848507  0.892674
#                    1                     0.869588  0.853534  0.890771
# hosp_admit_src_cat Direct Admit          0.859629  0.831119  0.871260
#                    Emergency Department  0.884005  0.874464  0.908673
#                    Floor                 0.813998  0.802630  0.852731
#                    Operating Room        0.804974  0.829387  0.840542
#                    Other Hospital        0.863995  0.835125  0.866777
#                    Other ICU             0.750000  0.568750  0.787500
#                    PACU                  0.887629  0.809278  0.910309
#                    Recovery Room         0.897309  0.903121  0.910285
#                    Step-Down Unit (SDU)  0.848875  0.812644  0.839757
#                    Unknown               0.852376  0.824420  0.876498
#
#                                                f1
# model                                      LogReg       MLP   XGBoost
# demographic        group
# age_group          mid                   0.416422  0.410989  0.418712
#                    old                   0.398767  0.439105  0.425035
#                    young                 0.383202  0.401691  0.406002
# ethnicity_cat      Asian                 0.358974  0.482759  0.361446
#                    Caucasian             0.408197  0.423225  0.426832
#                    Hispanic              0.384365  0.413793  0.424658
#                    Native American       0.171429  0.200000  0.176471
#                    Other/Unknown         0.394052  0.485437  0.426230
#                    Unknown               0.380952  0.395161  0.376206
# gender             0                     0.401580  0.425287  0.426311
#                    1                     0.401989  0.419032  0.411460
# hosp_admit_src_cat Direct Admit          0.393235  0.480000  0.417391
#                    Emergency Department  0.412146  0.458801  0.432149
#                    Floor                 0.426639  0.424691  0.462719
#                    Operating Room        0.322581  0.352000  0.348684
#                    Other Hospital        0.449438  0.389610  0.490798
#                    Other ICU             0.516129  0.133333  0.600000
#                    PACU                  0.300000  0.500000  0.214286
#                    Recovery Room         0.421053  0.333333  0.428571
#                    Step-Down Unit (SDU)  0.521212  0.523810  0.518987
#                    Unknown               0.365265  0.350263  0.369393

# %%
from sklearn.metrics import accuracy_score

y_prob_lr = log_clf_bal.predict_proba(X_test)[:,1]
y_pred_lr = (y_prob_lr  >= 0.5).astype(int)

y_prob_xgb = xgb_clf.predict_proba(X_test)[:,1]
y_pred_xgb = (y_prob_xgb >= 0.5).astype(int)

y_prob_mlp = model_mc.predict(X_test_np, batch_size=256)
y_pred_mlp = y_prob_mlp.argmax(axis=1)

models = [("LogReg", y_pred_lr), ("XGBoost", y_pred_xgb), ("MLP Softmax", y_pred_mlp)]

demographics = ['gender','ethnicity_cat','hosp_admit_src_cat','age_group']

records = []
for name, y_pred in models:
    for axis in demographics:
        for grp in df_test[axis].unique():
            mask = df_test[axis] == grp
            if mask.sum() < 30:
                continue
            ba = accuracy_score(y_test[mask], y_pred[mask])
            records.append({
                'model': name,
                'demographic': axis,
                'group': grp,
                'balanced_accuracy': ba,
                'n_samples': mask.sum(),
                'prevalence': df_test.loc[mask,'hospital_death'].mean()
            })
df_bal = pd.DataFrame(records)

for axis in demographics:
    df_axis = df_bal[df_bal['demographic']==axis]
    groups  = list(df_axis['group'].unique())
    x = np.arange(len(groups))
    width = 0.25

    fig, (ax_ba, ax_n, ax_p) = plt.subplots(1,3, figsize=(len(groups)*0.5+20, 5))
    for i,(name,_) in enumerate(models):
        vals = [df_axis[(df_axis['model']==name)&(df_axis['group']==g)]['balanced_accuracy'].iloc[0]
                for g in groups ]
        ax_ba.bar(x + i*width, vals, width, label=name)
    ax_ba.set_xticks(x + width*(len(models)-1)/2)
    ax_ba.set_xticklabels(groups, rotation=45, ha='right')
    ax_ba.set_title(f'Acc by {axis}')
    ax_ba.set_ylabel('Accuracy')
    ax_ba.legend(loc='lower left')

    counts = [df_axis[df_axis['group']==g]['n_samples'].iloc[0] for g in groups ]
    ax_n.bar(x, counts, width)
    ax_n.set_xticks(x); ax_n.set_xticklabels(groups, rotation=45, ha='right')
    ax_n.set_title('Group Size'); ax_n.set_ylabel('n samples')

    prevs = [df_axis[df_axis['group']==g]['prevalence'].iloc[0] for g in groups ]
    ax_p.bar(x, prevs, width)
    ax_p.set_xticks(x); ax_p.set_xticklabels(groups, rotation=45, ha='right')
    ax_p.set_title('Death Rate'); ax_p.set_ylabel('Prevalence')
# Out:
# 72/72 [==============================] - 0s 955us/step

# %%
log_coefs = pd.Series(log_clf_bal.coef_.ravel(), index=X_train.columns)
top10_log = log_coefs.abs().sort_values(ascending=False).head(10)
print("=== Top 10 Logistic Regression Coefficients (abs) ===")
print(top10_log.to_string(), "\n")

xgb_imp = pd.Series(xgb_clf.feature_importances_, index=X_train.columns)
top10_xgb = xgb_imp.sort_values(ascending=False).head(10)
print("=== Top 10 XGBoost Feature Importances ===")
print(top10_xgb.to_string(), "\n")
# Out:
# === Top 10 Logistic Regression Coefficients (abs) ===
# apache_2_diagnosis_123.0       1.819107
# icu_admit_source_Other ICU     1.329518
# apache_2_diagnosis_208.0       1.254416
# apache_2_diagnosis_217.0       0.949920
# apache_2_diagnosis_114.0       0.879612
# ventilated_apache              0.847378
# solid_tumor_with_metastasis    0.812705
# apache_2_diagnosis_124.0       0.805920
# apache_2_diagnosis_219.0       0.802351
# gcs_unable_apache              0.791865
#
# === Top 10 XGBoost Feature Importances ===
# apache_4a_hospital_death_prob           0.094063
# ventilated_apache                       0.019787
# hospital_admit_source_Other Hospital    0.014018
# icu_admit_source_Other ICU              0.012795
# d1_spo2_min                             0.012627
# d1_sysbp_min                            0.011325
# apache_2_diagnosis_114.0                0.010777
# gcs_motor_apache                        0.010368
# solid_tumor_with_metastasis             0.010259
# icu_type_CSICU                          0.010042

# %%
y_prob_mlp = model_mc.predict(X_test_np)
y_prob_mlp1 = y_prob_mlp[:,1]

baseline_auc = roc_auc_score(y_test_int, y_prob_mlp1)

importances = {}
for col in X_test.columns:
    X_perm = X_test.copy()
    X_perm[col] = np.random.permutation(X_perm[col].values)
    # remember to convert to numpy float32 if X_test_np is used:
    X_perm_np = X_perm.to_numpy().astype("float32")
    y_prob_perm = model_mc.predict(X_perm_np)[:, 1]
    perm_auc = roc_auc_score(y_test_int, y_prob_perm)
    importances[col] = baseline_auc - perm_auc

imp = pd.Series(importances).sort_values(ascending=False)
print("Top 10 MLP features (manual permutation importance):")
print(imp.head(10).to_string())
# Out:
# 574/574 [==============================] - 0s 508us/step
# 574/574 [==============================] - 0s 584us/step
# 574/574 [==============================] - 0s 467us/step
# 574/574 [==============================] - 0s 477us/step
# 574/574 [==============================] - 0s 467us/step
# 574/574 [==============================] - 0s 470us/step
# 574/574 [==============================] - 0s 484us/step
# 574/574 [==============================] - 0s 472us/step
# 574/574 [==============================] - 0s 469us/step
# 574/574 [==============================] - 0s 523us/step
# 574/574 [==============================] - 0s 586us/step
# 574/574 [==============================] - 0s 529us/step
# 574/574 [==============================] - 0s 568us/step
# 574/574 [==============================] - 0s 577us/step
# 574/574 [==============================] - 0s 489us/step
# 574/574 [==============================] - 0s 494us/step
# 574/574 [==============================] - 0s 460us/step
# 574/574 [==============================] - 0s 497us/step
# 574/574 [==============================] - 0s 474us/step
# 574/574 [==============================] - 0s 487us/step
# 574/574 [==============================] - 0s 481us/step
# 574/574 [==============================] - 0s 556us/step
# 574/574 [==============================] - 0s 494us/step
# 574/574 [==============================] - 0s 496us/step
# 574/574 [==============================] - 0s 491us/step
# 574/574 [==============================] - 0s 508us/step
# 574/574 [==============================] - 0s 487us/step
# 574/574 [==============================] - 0s 477us/step
# 574/574 [==============================] - 0s 475us/step
# 574/574 [==============================] - 0s 489us/step
# 574/574 [==============================] - 0s 479us/step
# 574/574 [==============================] - 0s 462us/step
# 574/574 [==============================] - 0s 525us/step
# 574/574 [==============================] - 0s 574us/step
# 574/574 [==============================] - 0s 541us/step
# 574/574 [==============================] - 0s 500us/step
# 574/574 [==============================] - 0s 492us/step
# 574/574 [==============================] - 0s 539us/step
# 574/574 [==============================] - 0s 544us/step
# 574/574 [==============================] - 0s 524us/step
# 574/574 [==============================] - 0s 584us/step
# 574/574 [==============================] - 0s 512us/step
# 574/574 [==============================] - 0s 508us/step
# 574/574 [==============================] - 0s 510us/step
# 574/574 [==============================] - 0s 520us/step
# 574/574 [==============================] - 0s 575us/step
# 574/574 [==============================] - 0s 588us/step
# 574/574 [==============================] - 0s 518us/step
# 574/574 [==============================] - 0s 520us/step
# 574/574 [==============================] - 0s 583us/step
# 574/574 [==============================] - 0s 660us/step
# 574/574 [==============================] - 0s 580us/step
# 574/574 [==============================] - 0s 536us/step
# 574/574 [==============================] - 0s 505us/step
# 574/574 [==============================] - 0s 533us/step
# 574/574 [==============================] - 0s 542us/step
# 574/574 [==============================] - 0s 483us/step
# 574/574 [==============================] - 0s 535us/step
# 574/574 [==============================] - 0s 499us/step
# 574/574 [==============================] - 0s 524us/step
# 574/574 [==============================] - 0s 515us/step
# 574/574 [==============================] - 0s 513us/step
# 574/574 [==============================] - 0s 494us/step
# 574/574 [==============================] - 0s 497us/step
# 574/574 [==============================] - 0s 487us/step
# 574/574 [==============================] - 0s 500us/step
# 574/574 [==============================] - 0s 489us/step
# 574/574 [==============================] - 0s 486us/step
# 574/574 [==============================] - 0s 485us/step
# 574/574 [==============================] - 0s 495us/step
# 574/574 [==============================] - 0s 542us/step
# 574/574 [==============================] - 0s 478us/step
# 574/574 [==============================] - 0s 505us/step
# 574/574 [==============================] - 0s 518us/step
# 574/574 [==============================] - 0s 476us/step
# 574/574 [==============================] - 0s 534us/step
# 574/574 [==============================] - 0s 588us/step
# 574/574 [==============================] - 0s 549us/step
# 574/574 [==============================] - 0s 498us/step
# 574/574 [==============================] - 0s 495us/step
# 574/574 [==============================] - 0s 493us/step
# 574/574 [==============================] - 0s 533us/step
# 574/574 [==============================] - 0s 485us/step
# 574/574 [==============================] - 0s 487us/step
# 574/574 [==============================] - 0s 478us/step
# 574/574 [==============================] - 0s 488us/step
# 574/574 [==============================] - 0s 500us/step
# 574/574 [==============================] - 0s 470us/step
# 574/574 [==============================] - 0s 492us/step
# 574/574 [==============================] - 0s 487us/step
# 574/574 [==============================] - 0s 490us/step
# 574/574 [==============================] - 0s 563us/step
# 574/574 [==============================] - 0s 457us/step
# 574/574 [==============================] - 0s 548us/step
# 574/574 [==============================] - 0s 509us/step
# 574/574 [==============================] - 0s 481us/step
# 574/574 [==============================] - 0s 509us/step
# 574/574 [==============================] - 0s 493us/step
# 574/574 [==============================] - 0s 542us/step
# 574/574 [==============================] - 0s 520us/step
# 574/574 [==============================] - 0s 503us/step
# 574/574 [==============================] - 0s 481us/step
# 574/574 [==============================] - 0s 480us/step
# 574/574 [==============================] - 0s 486us/step
# 574/574 [==============================] - 0s 518us/step
# 574/574 [==============================] - 0s 519us/step
# 574/574 [==============================] - 0s 495us/step
# 574/574 [==============================] - 0s 551us/step
# 574/574 [==============================] - 0s 470us/step
# 574/574 [==============================] - 0s 498us/step
# 574/574 [==============================] - 0s 505us/step
# 574/574 [==============================] - 0s 500us/step
# 574/574 [==============================] - 0s 497us/step
# 574/574 [==============================] - 0s 476us/step
# 574/574 [==============================] - 0s 494us/step
# 574/574 [==============================] - 0s 504us/step
# 574/574 [==============================] - 0s 492us/step
# 574/574 [==============================] - 0s 486us/step
# 574/574 [==============================] - 0s 483us/step
# 574/574 [==============================] - 0s 454us/step
# 574/574 [==============================] - 0s 532us/step
# 574/574 [==============================] - 0s 531us/step
# 574/574 [==============================] - 0s 471us/step
# 574/574 [==============================] - 0s 509us/step
# 574/574 [==============================] - 0s 492us/step
# 574/574 [==============================] - 0s 481us/step
# 574/574 [==============================] - 0s 486us/step
# 574/574 [==============================] - 0s 588us/step
# 574/574 [==============================] - 0s 520us/step
# 574/574 [==============================] - 0s 571us/step
# 574/574 [==============================] - 0s 529us/step
# 574/574 [==============================] - 0s 492us/step
# 574/574 [==============================] - 0s 489us/step
# 574/574 [==============================] - 0s 567us/step
# 574/574 [==============================] - 0s 471us/step
# 574/574 [==============================] - 0s 512us/step
# 574/574 [==============================] - 0s 573us/step
# 574/574 [==============================] - 0s 590us/step
# 574/574 [==============================] - 0s 538us/step
# 574/574 [==============================] - 0s 505us/step
# 574/574 [==============================] - 0s 499us/step
# Top 10 MLP features (manual permutation importance):
# apache_4a_hospital_death_prob    0.034165
# age                              0.013250
# d1_heartrate_min                 0.010739
# ventilated_apache                0.010529
# gcs_motor_apache                 0.009765
# d1_spo2_min                      0.008647
# bun_apache                       0.006112
# d1_sysbp_max                     0.005399
# d1_temp_max                      0.005034
# d1_platelets_min                 0.004466

# %%
# log_clf = LogisticRegression(max_iter=3000,
#                              class_weight=class_weight_dict,
#                              penalty = "l2",
#                              solver="lbfgs",
#                              n_jobs=-1,
#                              random_state=RANDOM_SEED)

# log_clf.fit(X_train, y_train)
# y_prob_lr = log_clf.predict_proba(X_test)[:, 1]
# results.append(evaluate("Logistic Regression", y_test, y_prob_lr))

# y_pred_logreg = log_clf.predict(X_test)
# y_proba = log_clf.predict_proba(X_test)[:,1]

# cm = confusion_matrix(y_test, y_pred)
# tn, fp, fn, tp = cm.ravel()
# print("Confusion Matrix:")
# print(f"TN = {tn}, FP = {fp}")
# print(f"FN = {fn}, TP = {tp}\n")

# print("Classification Report:")
# print(classification_report(y_test, y_pred_logreg, digits=4))

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
# from tensorflow.keras.utils import to_categorical
# from sklearn.metrics import classification_report, roc_auc_score

# y_train_cat = to_categorical(y_train, num_classes=2)
# y_test_cat  = to_categorical(y_test,  num_classes=2)

# input_dim = X_train.shape[1]
# model_mc = Sequential([
#     Dense(512, activation='relu', input_shape=(input_dim,)),
#     BatchNormalization(),
#     Dropout(.1),
#     Dense(256, activation="relu"),
#     BatchNormalization(), 
#     Dropout(0.1),
#     Dense(128, activation="relu"),
#     BatchNormalization(), 
#     Dropout(0.1),
#     Dense(64, activation="relu"), 
#     BatchNormalization(), 
#     Dropout(0.1),
#     Dense(2, activation="softmax")])

# model_mc.compile(
#     optimizer=tf.keras.optimizers.Adam(1e-3),
#     loss="categorical_crossentropy",
#     metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])

# history_mc = model_mc.fit(X_train, y_train_cat, validation_split=0.15, epochs=50, batch_size=256)

# loss, acc, auc_mc = model_mc.evaluate(X_test, y_test_cat, verbose=0)
# print(f"Test loss: {loss:.4f}, Test acc: {acc:.4f}, Test AUC: {auc_mc:.4f}")

# y_prob_mc = model_mc.predict(X_test)
# y_pred_mc = y_prob_mc.argmax(axis=1)

# print(evaluate("thing", y_test, y_prob_mc[:,1]))
# print(classification_report(y_test, y_pred_mc, digits=4))
# print("ROC AUC (class-1):", roc_auc_score(y_test, y_prob_mc[:,1]))
# results.append(evaluate("MultiClass MLP", y_test, y_prob_mc[:,1]))

# %%
X_train.head()
# Out:
#         age       bmi  elective_surgery  gender  pre_icu_los_days  \
# 0 -2.467390  0.018740                 0       0         -0.307972
# 1  0.706394 -1.245324                 0       0         -0.226068
# 2  0.706394 -0.180558                 1       0         -0.336764
# 3 -2.650493 -0.272220                 0       0         -0.332851
# 4  0.401223 -0.416137                 1       1         -0.237250
#
#    apache_post_operative  arf_apache  bun_apache  creatinine_apache  \
# 0                      1           0   -0.612535          -0.564234
# 1                      0           0   -0.666347          -0.564234
# 2                      1           0   -0.289661          -0.287850
# 3                      0           0   -0.881597          -0.273303
# 4                      1           0    1.486149           0.192186
#
#    gcs_motor_apache  ...  apache_2_diagnosis_218.0  apache_2_diagnosis_219.0  \
# 0          0.405439  ...                     False                     False
# 1          0.405439  ...                     False                     False
# 2          0.405439  ...                     False                     False
# 3          0.405439  ...                     False                     False
# 4          0.405439  ...                     False                     False
#
#    apache_2_diagnosis_301.0  apache_2_diagnosis_302.0  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    apache_2_diagnosis_303.0  apache_2_diagnosis_304.0  \
# 0                     False                      True
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    apache_2_diagnosis_305.0  apache_2_diagnosis_306.0  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
#    apache_2_diagnosis_307.0  apache_2_diagnosis_308.0
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
#
# [5 rows x 140 columns]

# %% [markdown]
# ### This takes forever to run

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=2)

batch_size = 256
train_ds = (tf.data.Dataset.from_tensor_slices((X_train.values.astype(np.float32), y_train_cat.astype(np.float32))).batch(batch_size).prefetch(1))

norms = []
for X_batch, y_batch in train_ds.take(20):
    for i in range(X_batch.shape[0]):
        x_i = tf.expand_dims(X_batch[i], 0)
        y_i = tf.expand_dims(y_batch[i], 0)
        with tf.GradientTape() as tape:
            preds = model_mc(x_i, training=False)
            loss  = tf.keras.losses.categorical_crossentropy(y_i, preds)
        grads = tape.gradient(loss, model_mc.trainable_variables)
        grad_norm = tf.linalg.global_norm(grads).numpy()
        norms.append(grad_norm)

print("Gradient norm percentiles:", np.percentile(norms, [50,80,90,95,99]))
# Out:
# Gradient norm percentiles: [2.26206053e-03 2.03861186e-01 1.05750426e+00 2.62249424e+00
#  1.00034546e+01]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras import DPKerasAdamOptimizer
from sklearn.model_selection import train_test_split

X_np = X_train.to_numpy().astype("float32")
y_np = to_categorical(y_train, num_classes=2).astype("float32")

batch_size = 256
microbatches = 1
noise_multiplier = 1.1
l2_norm_clip = np.percentile(norms, 80)
epochs = 5

# 3) Build your DP-SGD model
input_dim = X_np.shape[1]
model_dp = Sequential([
    Dense(512, activation='relu', input_shape=(X_train_np.shape[1],)),
    BatchNormalization(),
    Dropout(0.25),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),
    Dense(2, activation="softmax")])

optimizer = DPKerasAdamOptimizer(
    l2_norm_clip= l2_norm_clip,
    noise_multiplier= noise_multiplier,
    num_microbatches= microbatches,
    learning_rate= 1e-3)

model_dp.compile(
    optimizer= optimizer,
    loss= "categorical_crossentropy",
    metrics=[ "accuracy", tf.keras.metrics.AUC(name="auc") ])

history_dp = model_dp.fit(X_np, y_np,validation_split=.15,epochs=epochs, verbose=2)

from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy_lib

eps, _ = compute_dp_sgd_privacy_lib.compute_dp_sgd_privacy(
    n=X_np.shape[0],
    batch_size=batch_size,
    noise_multiplier=noise_multiplier,
    epochs=epochs,
    delta=1e-5
)

print(f"≈ε spent for δ=1e-5 → {eps:.3f}")


print(f"≈ε spent for δ=1e-5 → {eps:.3f}")

X_test_np  = X_test.to_numpy().astype("float32")
y_test_np  = to_categorical(y_test, num_classes=2).astype("float32")

loss_dp, acc_dp, auc_dp = model_dp.evaluate(X_test_np, y_test_np, verbose=0)
print(f"DP-SGD Test  loss: {loss_dp:.4f}, acc: {acc_dp:.4f}, AUC: {auc_dp:.4f}")

y_prob_dp = model_dp.predict(X_test_np)[:,1]
y_pred_dp = (y_prob_dp >= 0.5).astype(int)
# Out:
# Epoch 1/5
# 1949/1949 - 8s - loss: 1.0136 - accuracy: 0.5504 - auc: 0.5699 - val_loss: 0.6248 - val_accuracy: 0.6827 - val_auc: 0.7356 - 8s/epoch - 4ms/step
# Epoch 2/5
# 1949/1949 - 6s - loss: 0.7813 - accuracy: 0.6510 - auc: 0.6989 - val_loss: 0.4080 - val_accuracy: 0.8460 - val_auc: 0.9033 - 6s/epoch - 3ms/step
# Epoch 3/5
# 1949/1949 - 6s - loss: 0.6914 - accuracy: 0.7024 - auc: 0.7563 - val_loss: 0.3868 - val_accuracy: 0.8640 - val_auc: 0.9102 - 6s/epoch - 3ms/step
# Epoch 4/5
# 1949/1949 - 6s - loss: 0.6175 - accuracy: 0.7340 - auc: 0.7974 - val_loss: 0.3546 - val_accuracy: 0.8889 - val_auc: 0.9205 - 6s/epoch - 3ms/step
# Epoch 5/5
# 1949/1949 - 6s - loss: 0.5414 - accuracy: 0.7742 - auc: 0.8390 - val_loss: 0.2861 - val_accuracy: 0.9118 - val_auc: 0.9422 - 6s/epoch - 3ms/step
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# ≈ε spent for δ=1e-5 → 0.840
# ≈ε spent for δ=1e-5 → 0.840
# DP-SGD Test  loss: 0.2970, acc: 0.9025, AUC: 0.9385
# 574/574 [==============================] - 0s 598us/step

# %%
import numpy as np
import tensorflow as tf
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras import DPKerasAdamOptimizer

def evaluate(name, y_true, y_prob, threshold=0.5):
    y_pred = (y_prob >= threshold).astype(int)
    acc = accuracy_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_prob)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    print(f"\n=== {name} ===")
    print(f"Accuracy : {acc:.4f}")
    print(f"AUROC    : {auc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1 Score : {f1:.4f}")
    print("-" * 40)

    return {"model": name, "acc": acc, "auc": auc, "prec": prec, "rec": rec, "f1": f1}


def get_noise_multiplier(target_epsilon):
    """ Rough mapping: higher epsilon → lower noise. """
    noise_multiplier = max(0.5, 2.0 / target_epsilon)
    return noise_multiplier


def train_and_evaluate_dp_models(target_epsilon, X_train, y_train, X_test, y_test, RANDOM_SEED=42):
    results = []

    # Preprocessing
    X_train_np = X_train.to_numpy().astype("float32")
    X_test_np  = X_test.to_numpy().astype("float32")
    y_train_np = y_train.to_numpy().astype("int32")
    y_test_np  = y_test.to_numpy().astype("int32")
    y_train_cat = tf.keras.utils.to_categorical(y_train_np, num_classes=2).astype("float32")
    y_test_cat  = tf.keras.utils.to_categorical(y_test_np,  num_classes=2).astype("float32")

    row_norms_train = np.linalg.norm(X_train_np, axis=1)
    X_train_clipped = X_train_np / np.maximum(1.0, row_norms_train).reshape(-1, 1)
    
    row_norms_test = np.linalg.norm(X_test_np, axis=1)
    X_test_clipped = X_test_np / np.maximum(1.0, row_norms_test).reshape(-1, 1)

    base_clf = LogisticRegression(
        penalty='l2',
        solver='lbfgs',
        C=1.0,
        max_iter=3000,
        random_state=RANDOM_SEED
    )
    base_clf.fit(X_train_clipped, y_train_np)

    sensitivity = 2.0 / (X_train_clipped.shape[0] * 1.0)
    delta = 1e-5

    sigma = sensitivity * np.sqrt(2 * np.log(1.25 / delta)) / target_epsilon
    print(f"LogReg Output Perturbation = {sigma:.6f}")

    base_clf.coef_ += np.random.normal(0, sigma, size=base_clf.coef_.shape)
    base_clf.intercept_ += np.random.normal(0, sigma, size=base_clf.intercept_.shape)

    y_prob_dp_logreg = base_clf.predict_proba(X_test_clipped)[:, 1]
    results.append(evaluate(f"DP Logistic ε={target_epsilon:.2f}", y_test_np, y_prob_dp_logreg))

    noise_multiplier = get_noise_multiplier(target_epsilon)
    batch_size = 256
    epochs = 25

    model_dp = Sequential([
        Dense(512, activation='relu', input_shape=(X_train_np.shape[1],)),
        BatchNormalization(),
        Dropout(0.25),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),
        Dense(2, activation="softmax")])

    optimizer = DPKerasAdamOptimizer(
        l2_norm_clip=np.percentile(np.linalg.norm(X_train_np, axis=1), 80),
        noise_multiplier=noise_multiplier,
        num_microbatches=1,
        learning_rate=1e-3)

    model_dp.compile( optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy", tf.keras.metrics.AUC(name="auc")])

    model_dp.fit(X_train_np, y_train_cat, validation_split=0.15, epochs=epochs, batch_size=batch_size,verbose=2)

    dp_y_prob_mlp = model_dp.predict(X_test_np, batch_size=batch_size)[:, 1]
    results.append(evaluate(f"DP MLP ε={target_epsilon:.2f}", y_test_np, dp_y_prob_mlp))

    return results


def sweep_epsilons(epsilon_list, X_train, y_train, X_test, y_test):
    all_results = []

    for eps in epsilon_list:
        print(f"\n====== Running for ε = {eps} ======")
        results = train_and_evaluate_dp_models(eps, X_train, y_train, X_test, y_test)
        all_results.extend(results)

    return all_results

# %%
epsilon_list = [.01, 0.5, 1.0, 2.0, 5.0, 10.0]

all_dp_results = sweep_epsilons(epsilon_list, X_bal, y_bal, X_test, y_test)

baseline_results = []
baseline_results.append(evaluate("Baseline Logistic", y_test, y_prob_lr))
baseline_results.append(evaluate("Baseline XGBoost", y_test, y_prob_xgb))
baseline_results.append(evaluate("Baseline MLP", y_test, y_prob_mlp[:,1]))

final_results = baseline_results + all_dp_results

plot_metric(final_results, metric='acc')
plot_metric(final_results, metric='auc')
plot_metric(final_results, metric='f1_weighted')
# Out:
# ====== Running for ε = 0.01 ======
# LogReg Output Perturbation = 0.076513
#
# === DP Logistic ε=0.01 ===
# Accuracy : 0.7660
# AUROC    : 0.8652
# Precision: 0.2425
# Recall   : 0.8061
# F1 Score : 0.3729
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.1674 - accuracy: 0.4902 - auc: 0.4878 - val_loss: 0.7023 - val_accuracy: 0.4779 - val_auc: 0.4871 - 2s/epoch - 45ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.1467 - accuracy: 0.5017 - auc: 0.4994 - val_loss: 0.7189 - val_accuracy: 0.4505 - val_auc: 0.4638 - 236ms/epoch - 5ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 1.1250 - accuracy: 0.5103 - auc: 0.5089 - val_loss: 0.7251 - val_accuracy: 0.4837 - val_auc: 0.4912 - 282ms/epoch - 7ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 1.1171 - accuracy: 0.5038 - auc: 0.5045 - val_loss: 0.7268 - val_accuracy: 0.4958 - val_auc: 0.5152 - 269ms/epoch - 6ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 1.1018 - accuracy: 0.5126 - auc: 0.5186 - val_loss: 0.7452 - val_accuracy: 0.4868 - val_auc: 0.5117 - 269ms/epoch - 6ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 1.0997 - accuracy: 0.5173 - auc: 0.5212 - val_loss: 0.7464 - val_accuracy: 0.5205 - val_auc: 0.5364 - 269ms/epoch - 6ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 1.0834 - accuracy: 0.5161 - auc: 0.5209 - val_loss: 0.7723 - val_accuracy: 0.5121 - val_auc: 0.5240 - 291ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 1.1044 - accuracy: 0.5112 - auc: 0.5132 - val_loss: 0.7707 - val_accuracy: 0.5300 - val_auc: 0.5457 - 268ms/epoch - 6ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 1.0797 - accuracy: 0.5174 - auc: 0.5256 - val_loss: 0.7841 - val_accuracy: 0.5247 - val_auc: 0.5429 - 266ms/epoch - 6ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 1.0865 - accuracy: 0.5101 - auc: 0.5183 - val_loss: 0.7777 - val_accuracy: 0.5311 - val_auc: 0.5501 - 272ms/epoch - 6ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 1.0379 - accuracy: 0.5245 - auc: 0.5379 - val_loss: 0.7902 - val_accuracy: 0.5284 - val_auc: 0.5468 - 271ms/epoch - 6ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 1.0817 - accuracy: 0.5146 - auc: 0.5248 - val_loss: 0.7894 - val_accuracy: 0.5442 - val_auc: 0.5601 - 270ms/epoch - 6ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 1.0604 - accuracy: 0.5251 - auc: 0.5354 - val_loss: 0.8100 - val_accuracy: 0.5311 - val_auc: 0.5440 - 270ms/epoch - 6ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 1.0826 - accuracy: 0.5085 - auc: 0.5227 - val_loss: 0.8083 - val_accuracy: 0.5405 - val_auc: 0.5501 - 267ms/epoch - 6ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 1.0515 - accuracy: 0.5272 - auc: 0.5372 - val_loss: 0.8170 - val_accuracy: 0.5300 - val_auc: 0.5459 - 275ms/epoch - 6ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 1.0541 - accuracy: 0.5200 - auc: 0.5343 - val_loss: 0.8084 - val_accuracy: 0.5247 - val_auc: 0.5535 - 271ms/epoch - 6ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 1.0560 - accuracy: 0.5255 - auc: 0.5399 - val_loss: 0.7858 - val_accuracy: 0.5426 - val_auc: 0.5655 - 273ms/epoch - 6ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 1.0522 - accuracy: 0.5313 - auc: 0.5391 - val_loss: 0.7829 - val_accuracy: 0.5447 - val_auc: 0.5634 - 269ms/epoch - 6ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 1.0536 - accuracy: 0.5302 - auc: 0.5408 - val_loss: 0.7847 - val_accuracy: 0.5379 - val_auc: 0.5578 - 269ms/epoch - 6ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 1.0610 - accuracy: 0.5270 - auc: 0.5374 - val_loss: 0.8190 - val_accuracy: 0.5263 - val_auc: 0.5368 - 269ms/epoch - 6ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 1.0763 - accuracy: 0.5177 - auc: 0.5270 - val_loss: 0.8276 - val_accuracy: 0.5226 - val_auc: 0.5324 - 268ms/epoch - 6ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 1.1012 - accuracy: 0.5147 - auc: 0.5203 - val_loss: 0.8359 - val_accuracy: 0.5232 - val_auc: 0.5296 - 269ms/epoch - 6ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 1.0991 - accuracy: 0.5169 - auc: 0.5203 - val_loss: 0.8389 - val_accuracy: 0.5126 - val_auc: 0.5249 - 266ms/epoch - 6ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 1.1076 - accuracy: 0.5118 - auc: 0.5165 - val_loss: 0.8363 - val_accuracy: 0.5232 - val_auc: 0.5282 - 267ms/epoch - 6ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 1.1035 - accuracy: 0.5059 - auc: 0.5113 - val_loss: 0.8079 - val_accuracy: 0.5379 - val_auc: 0.5519 - 266ms/epoch - 6ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=0.01 ===
# Accuracy : 0.5100
# AUROC    : 0.5300
# Precision: 0.0928
# Recall   : 0.5332
# F1 Score : 0.1581
# ----------------------------------------
#
# ====== Running for ε = 0.5 ======
# LogReg Output Perturbation = 0.001530
#
# === DP Logistic ε=0.50 ===
# Accuracy : 0.7816
# AUROC    : 0.8655
# Precision: 0.2539
# Recall   : 0.7896
# F1 Score : 0.3842
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.0566 - accuracy: 0.5248 - auc: 0.5344 - val_loss: 0.6576 - val_accuracy: 0.6163 - val_auc: 0.6649 - 2s/epoch - 43ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.0838 - accuracy: 0.5195 - auc: 0.5264 - val_loss: 0.6735 - val_accuracy: 0.5863 - val_auc: 0.6139 - 226ms/epoch - 5ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 1.0544 - accuracy: 0.5308 - auc: 0.5424 - val_loss: 0.6927 - val_accuracy: 0.5689 - val_auc: 0.5910 - 256ms/epoch - 6ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 1.0602 - accuracy: 0.5257 - auc: 0.5343 - val_loss: 0.7056 - val_accuracy: 0.5532 - val_auc: 0.5779 - 281ms/epoch - 7ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 1.0699 - accuracy: 0.5207 - auc: 0.5284 - val_loss: 0.7181 - val_accuracy: 0.5453 - val_auc: 0.5698 - 275ms/epoch - 6ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 1.0603 - accuracy: 0.5239 - auc: 0.5345 - val_loss: 0.7325 - val_accuracy: 0.5484 - val_auc: 0.5633 - 278ms/epoch - 6ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 1.0602 - accuracy: 0.5247 - auc: 0.5340 - val_loss: 0.7397 - val_accuracy: 0.5511 - val_auc: 0.5732 - 280ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 1.0526 - accuracy: 0.5281 - auc: 0.5413 - val_loss: 0.7469 - val_accuracy: 0.5447 - val_auc: 0.5703 - 271ms/epoch - 6ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 1.0526 - accuracy: 0.5298 - auc: 0.5362 - val_loss: 0.7545 - val_accuracy: 0.5416 - val_auc: 0.5726 - 273ms/epoch - 6ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 1.0574 - accuracy: 0.5233 - auc: 0.5307 - val_loss: 0.7562 - val_accuracy: 0.5500 - val_auc: 0.5791 - 271ms/epoch - 6ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 1.0292 - accuracy: 0.5347 - auc: 0.5437 - val_loss: 0.7496 - val_accuracy: 0.5547 - val_auc: 0.5923 - 269ms/epoch - 6ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 1.0263 - accuracy: 0.5343 - auc: 0.5462 - val_loss: 0.7684 - val_accuracy: 0.5532 - val_auc: 0.5828 - 270ms/epoch - 6ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 1.0433 - accuracy: 0.5322 - auc: 0.5436 - val_loss: 0.7604 - val_accuracy: 0.5632 - val_auc: 0.5898 - 272ms/epoch - 6ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 1.0202 - accuracy: 0.5348 - auc: 0.5509 - val_loss: 0.7599 - val_accuracy: 0.5589 - val_auc: 0.5935 - 271ms/epoch - 6ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 1.0259 - accuracy: 0.5373 - auc: 0.5501 - val_loss: 0.7815 - val_accuracy: 0.5463 - val_auc: 0.5690 - 271ms/epoch - 6ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 1.0629 - accuracy: 0.5186 - auc: 0.5293 - val_loss: 0.7981 - val_accuracy: 0.5342 - val_auc: 0.5564 - 274ms/epoch - 6ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 1.0503 - accuracy: 0.5184 - auc: 0.5300 - val_loss: 0.8120 - val_accuracy: 0.5311 - val_auc: 0.5483 - 274ms/epoch - 6ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 1.0805 - accuracy: 0.5112 - auc: 0.5159 - val_loss: 0.8312 - val_accuracy: 0.5321 - val_auc: 0.5437 - 277ms/epoch - 6ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 1.0954 - accuracy: 0.5099 - auc: 0.5138 - val_loss: 0.8454 - val_accuracy: 0.5121 - val_auc: 0.5271 - 276ms/epoch - 6ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 1.0953 - accuracy: 0.5038 - auc: 0.5125 - val_loss: 0.8424 - val_accuracy: 0.5168 - val_auc: 0.5247 - 273ms/epoch - 6ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 1.0994 - accuracy: 0.5152 - auc: 0.5138 - val_loss: 0.8427 - val_accuracy: 0.5142 - val_auc: 0.5246 - 297ms/epoch - 7ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 1.0940 - accuracy: 0.5140 - auc: 0.5186 - val_loss: 0.8320 - val_accuracy: 0.5189 - val_auc: 0.5349 - 279ms/epoch - 6ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 1.0834 - accuracy: 0.5081 - auc: 0.5154 - val_loss: 0.8450 - val_accuracy: 0.5053 - val_auc: 0.5229 - 275ms/epoch - 6ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 1.1031 - accuracy: 0.5046 - auc: 0.5061 - val_loss: 0.8308 - val_accuracy: 0.5100 - val_auc: 0.5290 - 271ms/epoch - 6ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 1.0945 - accuracy: 0.5047 - auc: 0.5101 - val_loss: 0.8037 - val_accuracy: 0.5384 - val_auc: 0.5584 - 272ms/epoch - 6ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=0.50 ===
# Accuracy : 0.5544
# AUROC    : 0.5185
# Precision: 0.0912
# Recall   : 0.4643
# F1 Score : 0.1524
# ----------------------------------------
#
# ====== Running for ε = 1.0 ======
# LogReg Output Perturbation = 0.000765
#
# === DP Logistic ε=1.00 ===
# Accuracy : 0.7817
# AUROC    : 0.8655
# Precision: 0.2540
# Recall   : 0.7896
# F1 Score : 0.3844
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.2542 - accuracy: 0.4547 - auc: 0.4332 - val_loss: 0.7300 - val_accuracy: 0.4026 - val_auc: 0.3698 - 2s/epoch - 43ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.2233 - accuracy: 0.4634 - auc: 0.4482 - val_loss: 0.7737 - val_accuracy: 0.4205 - val_auc: 0.3943 - 231ms/epoch - 5ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 1.2376 - accuracy: 0.4560 - auc: 0.4356 - val_loss: 0.8036 - val_accuracy: 0.4284 - val_auc: 0.4006 - 267ms/epoch - 6ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 1.2227 - accuracy: 0.4601 - auc: 0.4439 - val_loss: 0.8248 - val_accuracy: 0.4363 - val_auc: 0.4124 - 283ms/epoch - 7ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 1.2127 - accuracy: 0.4584 - auc: 0.4433 - val_loss: 0.8565 - val_accuracy: 0.4468 - val_auc: 0.4202 - 286ms/epoch - 7ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 1.2109 - accuracy: 0.4643 - auc: 0.4477 - val_loss: 0.8505 - val_accuracy: 0.4600 - val_auc: 0.4401 - 290ms/epoch - 7ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 1.1906 - accuracy: 0.4634 - auc: 0.4565 - val_loss: 0.8584 - val_accuracy: 0.4616 - val_auc: 0.4442 - 292ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 1.1735 - accuracy: 0.4786 - auc: 0.4704 - val_loss: 0.8561 - val_accuracy: 0.4774 - val_auc: 0.4593 - 281ms/epoch - 7ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 1.1900 - accuracy: 0.4670 - auc: 0.4609 - val_loss: 0.8578 - val_accuracy: 0.4805 - val_auc: 0.4654 - 283ms/epoch - 7ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 1.1993 - accuracy: 0.4774 - auc: 0.4644 - val_loss: 0.8740 - val_accuracy: 0.4763 - val_auc: 0.4597 - 287ms/epoch - 7ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 1.1861 - accuracy: 0.4751 - auc: 0.4664 - val_loss: 0.8934 - val_accuracy: 0.4642 - val_auc: 0.4474 - 284ms/epoch - 7ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 1.1812 - accuracy: 0.4740 - auc: 0.4651 - val_loss: 0.9084 - val_accuracy: 0.4532 - val_auc: 0.4364 - 284ms/epoch - 7ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 1.2101 - accuracy: 0.4691 - auc: 0.4510 - val_loss: 0.9176 - val_accuracy: 0.4421 - val_auc: 0.4290 - 284ms/epoch - 7ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 1.1739 - accuracy: 0.4772 - auc: 0.4660 - val_loss: 0.8988 - val_accuracy: 0.4526 - val_auc: 0.4370 - 279ms/epoch - 6ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 1.1834 - accuracy: 0.4729 - auc: 0.4612 - val_loss: 0.8895 - val_accuracy: 0.4568 - val_auc: 0.4487 - 283ms/epoch - 7ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 1.1669 - accuracy: 0.4836 - auc: 0.4747 - val_loss: 0.8772 - val_accuracy: 0.4616 - val_auc: 0.4556 - 279ms/epoch - 6ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 1.1721 - accuracy: 0.4836 - auc: 0.4709 - val_loss: 0.8626 - val_accuracy: 0.4674 - val_auc: 0.4583 - 281ms/epoch - 7ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 1.1449 - accuracy: 0.4804 - auc: 0.4780 - val_loss: 0.8508 - val_accuracy: 0.4742 - val_auc: 0.4683 - 279ms/epoch - 6ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 1.1578 - accuracy: 0.4843 - auc: 0.4736 - val_loss: 0.8770 - val_accuracy: 0.4526 - val_auc: 0.4487 - 279ms/epoch - 6ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 1.1444 - accuracy: 0.4866 - auc: 0.4794 - val_loss: 0.8778 - val_accuracy: 0.4726 - val_auc: 0.4502 - 278ms/epoch - 6ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 1.1631 - accuracy: 0.4831 - auc: 0.4731 - val_loss: 0.8909 - val_accuracy: 0.4553 - val_auc: 0.4375 - 281ms/epoch - 7ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 1.1644 - accuracy: 0.4774 - auc: 0.4663 - val_loss: 0.8994 - val_accuracy: 0.4437 - val_auc: 0.4294 - 278ms/epoch - 6ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 1.1441 - accuracy: 0.4836 - auc: 0.4731 - val_loss: 0.8769 - val_accuracy: 0.4611 - val_auc: 0.4509 - 283ms/epoch - 7ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 1.1370 - accuracy: 0.4896 - auc: 0.4827 - val_loss: 0.8674 - val_accuracy: 0.4868 - val_auc: 0.4742 - 280ms/epoch - 7ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 1.1299 - accuracy: 0.4892 - auc: 0.4874 - val_loss: 0.8549 - val_accuracy: 0.4953 - val_auc: 0.4912 - 281ms/epoch - 7ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=1.00 ===
# Accuracy : 0.5212
# AUROC    : 0.5244
# Precision: 0.0930
# Recall   : 0.5193
# F1 Score : 0.1577
# ----------------------------------------
#
# ====== Running for ε = 2.0 ======
# LogReg Output Perturbation = 0.000383
#
# === DP Logistic ε=2.00 ===
# Accuracy : 0.7817
# AUROC    : 0.8655
# Precision: 0.2540
# Recall   : 0.7896
# F1 Score : 0.3844
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.1315 - accuracy: 0.4852 - auc: 0.4843 - val_loss: 0.7265 - val_accuracy: 0.4274 - val_auc: 0.4202 - 2s/epoch - 43ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.1068 - accuracy: 0.4983 - auc: 0.4992 - val_loss: 0.7289 - val_accuracy: 0.4463 - val_auc: 0.4728 - 233ms/epoch - 5ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 1.0948 - accuracy: 0.5060 - auc: 0.5046 - val_loss: 0.7308 - val_accuracy: 0.4600 - val_auc: 0.4880 - 267ms/epoch - 6ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 1.1054 - accuracy: 0.4932 - auc: 0.4979 - val_loss: 0.7364 - val_accuracy: 0.4779 - val_auc: 0.4981 - 276ms/epoch - 6ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 1.0776 - accuracy: 0.5059 - auc: 0.5094 - val_loss: 0.7395 - val_accuracy: 0.4979 - val_auc: 0.5147 - 285ms/epoch - 7ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 1.0668 - accuracy: 0.5093 - auc: 0.5149 - val_loss: 0.7448 - val_accuracy: 0.5137 - val_auc: 0.5284 - 281ms/epoch - 7ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 1.0918 - accuracy: 0.5067 - auc: 0.5103 - val_loss: 0.7546 - val_accuracy: 0.5258 - val_auc: 0.5380 - 282ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 1.0657 - accuracy: 0.5178 - auc: 0.5203 - val_loss: 0.7384 - val_accuracy: 0.5563 - val_auc: 0.5659 - 281ms/epoch - 7ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 1.0253 - accuracy: 0.5308 - auc: 0.5445 - val_loss: 0.7431 - val_accuracy: 0.5537 - val_auc: 0.5772 - 275ms/epoch - 6ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 1.0352 - accuracy: 0.5226 - auc: 0.5382 - val_loss: 0.7504 - val_accuracy: 0.5526 - val_auc: 0.5766 - 285ms/epoch - 7ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 1.0136 - accuracy: 0.5332 - auc: 0.5470 - val_loss: 0.7492 - val_accuracy: 0.5395 - val_auc: 0.5806 - 287ms/epoch - 7ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 1.0193 - accuracy: 0.5322 - auc: 0.5464 - val_loss: 0.7446 - val_accuracy: 0.5505 - val_auc: 0.5935 - 295ms/epoch - 7ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 1.0052 - accuracy: 0.5317 - auc: 0.5447 - val_loss: 0.7603 - val_accuracy: 0.5500 - val_auc: 0.5772 - 291ms/epoch - 7ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 1.0214 - accuracy: 0.5272 - auc: 0.5382 - val_loss: 0.7772 - val_accuracy: 0.5405 - val_auc: 0.5642 - 287ms/epoch - 7ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 0.9977 - accuracy: 0.5319 - auc: 0.5512 - val_loss: 0.7634 - val_accuracy: 0.5353 - val_auc: 0.5685 - 286ms/epoch - 7ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 0.9965 - accuracy: 0.5406 - auc: 0.5541 - val_loss: 0.7587 - val_accuracy: 0.5384 - val_auc: 0.5804 - 284ms/epoch - 7ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 0.9747 - accuracy: 0.5487 - auc: 0.5648 - val_loss: 0.7459 - val_accuracy: 0.5747 - val_auc: 0.5961 - 287ms/epoch - 7ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 0.9689 - accuracy: 0.5465 - auc: 0.5642 - val_loss: 0.7415 - val_accuracy: 0.5779 - val_auc: 0.6030 - 281ms/epoch - 7ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 0.9656 - accuracy: 0.5514 - auc: 0.5731 - val_loss: 0.7432 - val_accuracy: 0.5789 - val_auc: 0.6096 - 280ms/epoch - 7ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 0.9914 - accuracy: 0.5402 - auc: 0.5632 - val_loss: 0.7450 - val_accuracy: 0.5674 - val_auc: 0.5996 - 280ms/epoch - 7ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 0.9613 - accuracy: 0.5500 - auc: 0.5736 - val_loss: 0.7304 - val_accuracy: 0.5837 - val_auc: 0.6163 - 280ms/epoch - 7ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 0.9442 - accuracy: 0.5604 - auc: 0.5855 - val_loss: 0.7348 - val_accuracy: 0.5911 - val_auc: 0.6139 - 280ms/epoch - 7ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 0.9518 - accuracy: 0.5569 - auc: 0.5771 - val_loss: 0.7411 - val_accuracy: 0.5816 - val_auc: 0.6075 - 278ms/epoch - 6ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 0.9439 - accuracy: 0.5600 - auc: 0.5832 - val_loss: 0.7192 - val_accuracy: 0.5968 - val_auc: 0.6287 - 279ms/epoch - 6ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 0.9370 - accuracy: 0.5582 - auc: 0.5826 - val_loss: 0.7040 - val_accuracy: 0.5963 - val_auc: 0.6404 - 278ms/epoch - 6ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=2.00 ===
# Accuracy : 0.5410
# AUROC    : 0.6703
# Precision: 0.1219
# Recall   : 0.6961
# F1 Score : 0.2075
# ----------------------------------------
#
# ====== Running for ε = 5.0 ======
# LogReg Output Perturbation = 0.000153
#
# === DP Logistic ε=5.00 ===
# Accuracy : 0.7817
# AUROC    : 0.8655
# Precision: 0.2540
# Recall   : 0.7896
# F1 Score : 0.3844
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.1517 - accuracy: 0.4810 - auc: 0.4686 - val_loss: 0.7228 - val_accuracy: 0.4400 - val_auc: 0.4424 - 2s/epoch - 44ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.1380 - accuracy: 0.4825 - auc: 0.4751 - val_loss: 0.7130 - val_accuracy: 0.4811 - val_auc: 0.5085 - 240ms/epoch - 6ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 1.1098 - accuracy: 0.4864 - auc: 0.4846 - val_loss: 0.7089 - val_accuracy: 0.5142 - val_auc: 0.5325 - 270ms/epoch - 6ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 1.0906 - accuracy: 0.4970 - auc: 0.4939 - val_loss: 0.7188 - val_accuracy: 0.5037 - val_auc: 0.5295 - 287ms/epoch - 7ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 1.0837 - accuracy: 0.5004 - auc: 0.5036 - val_loss: 0.7324 - val_accuracy: 0.5126 - val_auc: 0.5408 - 286ms/epoch - 7ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 1.0748 - accuracy: 0.5119 - auc: 0.5118 - val_loss: 0.7278 - val_accuracy: 0.5374 - val_auc: 0.5692 - 285ms/epoch - 7ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 1.0389 - accuracy: 0.5204 - auc: 0.5303 - val_loss: 0.7282 - val_accuracy: 0.5468 - val_auc: 0.5798 - 282ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 0.9917 - accuracy: 0.5381 - auc: 0.5528 - val_loss: 0.7146 - val_accuracy: 0.5684 - val_auc: 0.6072 - 276ms/epoch - 6ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 0.9984 - accuracy: 0.5417 - auc: 0.5544 - val_loss: 0.7225 - val_accuracy: 0.5763 - val_auc: 0.6078 - 280ms/epoch - 7ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 0.9857 - accuracy: 0.5384 - auc: 0.5536 - val_loss: 0.7184 - val_accuracy: 0.5942 - val_auc: 0.6230 - 283ms/epoch - 7ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 0.9812 - accuracy: 0.5408 - auc: 0.5545 - val_loss: 0.7412 - val_accuracy: 0.5674 - val_auc: 0.6021 - 290ms/epoch - 7ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 0.9686 - accuracy: 0.5457 - auc: 0.5596 - val_loss: 0.7544 - val_accuracy: 0.5621 - val_auc: 0.5906 - 283ms/epoch - 7ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 0.9772 - accuracy: 0.5398 - auc: 0.5588 - val_loss: 0.7311 - val_accuracy: 0.5837 - val_auc: 0.6175 - 280ms/epoch - 7ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 0.9524 - accuracy: 0.5555 - auc: 0.5726 - val_loss: 0.7281 - val_accuracy: 0.5863 - val_auc: 0.6232 - 279ms/epoch - 6ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 0.9284 - accuracy: 0.5602 - auc: 0.5816 - val_loss: 0.7113 - val_accuracy: 0.6026 - val_auc: 0.6397 - 288ms/epoch - 7ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 0.9452 - accuracy: 0.5532 - auc: 0.5756 - val_loss: 0.6948 - val_accuracy: 0.6121 - val_auc: 0.6552 - 290ms/epoch - 7ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 0.9314 - accuracy: 0.5618 - auc: 0.5855 - val_loss: 0.6815 - val_accuracy: 0.6258 - val_auc: 0.6708 - 288ms/epoch - 7ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 0.8951 - accuracy: 0.5771 - auc: 0.6080 - val_loss: 0.6619 - val_accuracy: 0.6384 - val_auc: 0.6908 - 292ms/epoch - 7ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 0.8885 - accuracy: 0.5797 - auc: 0.6126 - val_loss: 0.6682 - val_accuracy: 0.6342 - val_auc: 0.6876 - 289ms/epoch - 7ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 0.8944 - accuracy: 0.5771 - auc: 0.6091 - val_loss: 0.6756 - val_accuracy: 0.6289 - val_auc: 0.6810 - 290ms/epoch - 7ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 0.8900 - accuracy: 0.5877 - auc: 0.6138 - val_loss: 0.6671 - val_accuracy: 0.6300 - val_auc: 0.6843 - 290ms/epoch - 7ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 0.8859 - accuracy: 0.5792 - auc: 0.6116 - val_loss: 0.6511 - val_accuracy: 0.6400 - val_auc: 0.7039 - 298ms/epoch - 7ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 0.8653 - accuracy: 0.5934 - auc: 0.6262 - val_loss: 0.6490 - val_accuracy: 0.6489 - val_auc: 0.7025 - 287ms/epoch - 7ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 0.8648 - accuracy: 0.5957 - auc: 0.6279 - val_loss: 0.6485 - val_accuracy: 0.6411 - val_auc: 0.7034 - 285ms/epoch - 7ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 0.8705 - accuracy: 0.5899 - auc: 0.6296 - val_loss: 0.6392 - val_accuracy: 0.6537 - val_auc: 0.7122 - 289ms/epoch - 7ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=5.00 ===
# Accuracy : 0.6553
# AUROC    : 0.7112
# Precision: 0.1532
# Recall   : 0.6614
# F1 Score : 0.2488
# ----------------------------------------
#
# ====== Running for ε = 10.0 ======
# LogReg Output Perturbation = 0.000077
#
# === DP Logistic ε=10.00 ===
# Accuracy : 0.7818
# AUROC    : 0.8655
# Precision: 0.2541
# Recall   : 0.7896
# F1 Score : 0.3844
# ----------------------------------------
# Epoch 1/25
# 43/43 - 2s - loss: 1.0287 - accuracy: 0.4926 - auc: 0.4915 - val_loss: 0.7023 - val_accuracy: 0.4995 - val_auc: 0.4916 - 2s/epoch - 44ms/step
# Epoch 2/25
# 43/43 - 0s - loss: 1.0071 - accuracy: 0.5042 - auc: 0.5040 - val_loss: 0.7007 - val_accuracy: 0.5174 - val_auc: 0.5230 - 241ms/epoch - 6ms/step
# Epoch 3/25
# 43/43 - 0s - loss: 0.9554 - accuracy: 0.5236 - auc: 0.5354 - val_loss: 0.6998 - val_accuracy: 0.5432 - val_auc: 0.5501 - 270ms/epoch - 6ms/step
# Epoch 4/25
# 43/43 - 0s - loss: 0.9345 - accuracy: 0.5324 - auc: 0.5440 - val_loss: 0.6982 - val_accuracy: 0.5558 - val_auc: 0.5744 - 288ms/epoch - 7ms/step
# Epoch 5/25
# 43/43 - 0s - loss: 0.9263 - accuracy: 0.5313 - auc: 0.5462 - val_loss: 0.6984 - val_accuracy: 0.5600 - val_auc: 0.5846 - 285ms/epoch - 7ms/step
# Epoch 6/25
# 43/43 - 0s - loss: 0.9122 - accuracy: 0.5392 - auc: 0.5570 - val_loss: 0.6886 - val_accuracy: 0.5763 - val_auc: 0.6140 - 288ms/epoch - 7ms/step
# Epoch 7/25
# 43/43 - 0s - loss: 0.8966 - accuracy: 0.5463 - auc: 0.5676 - val_loss: 0.6984 - val_accuracy: 0.5821 - val_auc: 0.6145 - 287ms/epoch - 7ms/step
# Epoch 8/25
# 43/43 - 0s - loss: 0.9055 - accuracy: 0.5443 - auc: 0.5604 - val_loss: 0.6890 - val_accuracy: 0.5979 - val_auc: 0.6320 - 291ms/epoch - 7ms/step
# Epoch 9/25
# 43/43 - 0s - loss: 0.8814 - accuracy: 0.5578 - auc: 0.5786 - val_loss: 0.6920 - val_accuracy: 0.6032 - val_auc: 0.6334 - 290ms/epoch - 7ms/step
# Epoch 10/25
# 43/43 - 0s - loss: 0.8927 - accuracy: 0.5546 - auc: 0.5692 - val_loss: 0.6788 - val_accuracy: 0.6189 - val_auc: 0.6558 - 290ms/epoch - 7ms/step
# Epoch 11/25
# 43/43 - 0s - loss: 0.8745 - accuracy: 0.5569 - auc: 0.5806 - val_loss: 0.6647 - val_accuracy: 0.6389 - val_auc: 0.6734 - 288ms/epoch - 7ms/step
# Epoch 12/25
# 43/43 - 0s - loss: 0.8790 - accuracy: 0.5610 - auc: 0.5804 - val_loss: 0.6548 - val_accuracy: 0.6405 - val_auc: 0.6839 - 283ms/epoch - 7ms/step
# Epoch 13/25
# 43/43 - 0s - loss: 0.8641 - accuracy: 0.5694 - auc: 0.5944 - val_loss: 0.6640 - val_accuracy: 0.6279 - val_auc: 0.6762 - 285ms/epoch - 7ms/step
# Epoch 14/25
# 43/43 - 0s - loss: 0.8511 - accuracy: 0.5779 - auc: 0.6003 - val_loss: 0.6583 - val_accuracy: 0.6305 - val_auc: 0.6845 - 285ms/epoch - 7ms/step
# Epoch 15/25
# 43/43 - 0s - loss: 0.8438 - accuracy: 0.5769 - auc: 0.6042 - val_loss: 0.6591 - val_accuracy: 0.6284 - val_auc: 0.6838 - 286ms/epoch - 7ms/step
# Epoch 16/25
# 43/43 - 0s - loss: 0.8500 - accuracy: 0.5755 - auc: 0.6067 - val_loss: 0.6499 - val_accuracy: 0.6537 - val_auc: 0.7013 - 283ms/epoch - 7ms/step
# Epoch 17/25
# 43/43 - 0s - loss: 0.8259 - accuracy: 0.5881 - auc: 0.6247 - val_loss: 0.6305 - val_accuracy: 0.6668 - val_auc: 0.7220 - 281ms/epoch - 7ms/step
# Epoch 18/25
# 43/43 - 0s - loss: 0.8204 - accuracy: 0.5872 - auc: 0.6241 - val_loss: 0.6244 - val_accuracy: 0.6658 - val_auc: 0.7280 - 282ms/epoch - 7ms/step
# Epoch 19/25
# 43/43 - 0s - loss: 0.8074 - accuracy: 0.6002 - auc: 0.6368 - val_loss: 0.6332 - val_accuracy: 0.6584 - val_auc: 0.7186 - 284ms/epoch - 7ms/step
# Epoch 20/25
# 43/43 - 0s - loss: 0.8224 - accuracy: 0.5937 - auc: 0.6267 - val_loss: 0.6391 - val_accuracy: 0.6589 - val_auc: 0.7111 - 286ms/epoch - 7ms/step
# Epoch 21/25
# 43/43 - 0s - loss: 0.8255 - accuracy: 0.5936 - auc: 0.6243 - val_loss: 0.6322 - val_accuracy: 0.6579 - val_auc: 0.7176 - 285ms/epoch - 7ms/step
# Epoch 22/25
# 43/43 - 0s - loss: 0.8115 - accuracy: 0.5963 - auc: 0.6296 - val_loss: 0.6350 - val_accuracy: 0.6637 - val_auc: 0.7135 - 283ms/epoch - 7ms/step
# Epoch 23/25
# 43/43 - 0s - loss: 0.8018 - accuracy: 0.5913 - auc: 0.6329 - val_loss: 0.6372 - val_accuracy: 0.6595 - val_auc: 0.7121 - 285ms/epoch - 7ms/step
# Epoch 24/25
# 43/43 - 0s - loss: 0.8079 - accuracy: 0.5940 - auc: 0.6288 - val_loss: 0.6482 - val_accuracy: 0.6453 - val_auc: 0.7047 - 288ms/epoch - 7ms/step
# Epoch 25/25
# 43/43 - 0s - loss: 0.7892 - accuracy: 0.6063 - auc: 0.6432 - val_loss: 0.6449 - val_accuracy: 0.6511 - val_auc: 0.7105 - 285ms/epoch - 7ms/step
# 72/72 [==============================] - 0s 1ms/step
#
# === DP MLP ε=10.00 ===
# Accuracy : 0.7711
# AUROC    : 0.7027
# Precision: 0.1893
# Recall   : 0.5035
# F1 Score : 0.2752
# ----------------------------------------
#
# === Baseline Logistic ===
# Accuracy : 0.8008
# AUROC    : 0.8692
# Precision: 0.2712
# Recall   : 0.7751
# F1 Score : 0.4018
# ----------------------------------------
#
# === Baseline XGBoost ===
# Accuracy : 0.8062
# AUROC    : 0.8916
# Precision: 0.2828
# Recall   : 0.8105
# F1 Score : 0.4193
# ----------------------------------------
#
# === Baseline MLP ===
# Accuracy : 0.9184
# AUROC    : 0.8508
# Precision: 0.5432
# Recall   : 0.3455
# F1 Score : 0.4224
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dp-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f1_weighted'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 14
#      12 plot_metric(final_results, metric='acc')
#      13 plot_metric(final_results, metric='auc')
# ---> 14 plot_metric(final_results, metric='f1_weighted')
#
# Cell In[5], line 32, in plot_metric(results, metric)
#      29 width = max(8, count * 0.4)
#      30 _, ax = plt.subplots(figsize=(width, 6))
# ---> 32 ax.bar(df['label'], df[metric])
#      33 ax.set_ylabel(metric.upper() + ' Score')
#      34 ax.set_title(f'{metric.upper()} Score by Model and Run')
#
# File /opt/anaconda3/envs/dp-env/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/dp-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'f1_weighted'
